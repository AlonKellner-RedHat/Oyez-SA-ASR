# %% [markdown]
# # Raw Dataset Demo
# Original MP3/OGG audio + JSON metadata. *Generated by Claude*

# %%
from oyez_sa_asr.loaders import load_raw

raw = load_raw()
print(f"Audio files: {len(raw['audio_files']):,}")
print(f"Transcripts: {len(raw['transcripts']):,}")
print(f"Cases: {len(raw['cases']):,}")
# Out:
# Audio files: 803
# Transcripts: 11,993
# Cases: 302

# %%
from IPython.display import Audio, display

# Play first audio file
if raw["audio_files"]:
    sample = raw["audio_files"][0]
    print(f"Playing: {sample.name}")
    display(Audio(filename=str(sample), normalize=True))
# Out:
# Playing: 19990303o_96-1793.delivery.mp3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       5 sample = raw["audio_files"][0]
#       6 print(f"Playing: {sample.name}")
# ----> 7 display(Audio(filename=str(sample, normalize=True)))
#
# TypeError: str() got an unexpected keyword argument 'normalize'
